# %%
# Data Preprocessing
# Read data from external file
import pandas as pd
dfCSV = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_data.csv")

# %%
dfCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   519 non-null    object
#  1   Medication  519 non-null    object
#  2   Family      519 non-null    object
#  3   Age         519 non-null    int64
#  4   Gender      519 non-null    object
#  5   Height      519 non-null    float64
#  6   Weight      519 non-null    float64
#  7   Status      519 non-null    object
#  8   Income      519 non-null    int64
#  9   Location    519 non-null    object
#  10  Education   519 non-null    object
#  11  Active      519 non-null    object
#  12  Exercise    519 non-null    float64
#  13  Veges       519 non-null    object
#  14  Water       519 non-null    int64
#  15  Sugar       518 non-null    float64
#  16  Outside     519 non-null    int64
#  17  Meal        519 non-null    int64
#  18  Snack       519 non-null    int64
# ...

# %%
dfCSV.head()
# Out:
#             Timestamp Medication Family  Age  Gender  Height  Weight   Status  \
# 0  5/20/2025 17:23:47         No     No   20  Female   151.0    55.0   Single
# 1  5/20/2025 17:28:08         No     No   22  Female   150.0    80.0   Single
# 2  5/20/2025 17:28:55         No    Yes   22  Female   150.0    45.0   Single
# 3  5/20/2025 17:29:48        Yes    Yes   22    Male   167.0    58.0   Single
# 4  5/20/2025 17:41:43         No    Yes   33  Female   159.0    88.0  Married
#
#    Income    Location  ... Outside Meal  Snack Smoke  Concious  \
# 0       0  Semi-urban  ...       7    2      1    No       Yes
# 1       0       Rural  ...       2    2      0    No       Yes
# 2       0  Semi-urban  ...       0    2      1    No       Yes
# 3    1100       Rural  ...       7    2      0    No       Yes
# 4    3000  Semi-urban  ...       4    3      2    No       Yes
#
#                  Stress  Sleep  Screen      Transport Diabetes
# ...

# %%
#Report missing data
dfCSV.isna().sum()
# Out:
# Timestamp     0
# Medication    0
# Family        0
# Age           0
# Gender        0
# Height        0
# Weight        0
# Status        0
# Income        0
# Location      0
# Education     0
# Active        0
# Exercise      0
# Veges         0
# Water         0
# Sugar         1
# Outside       0
# Meal          0
# Snack         0
# Smoke         0
# Concious      0
# Stress        0
# Sleep         0
# Screen        0
# Transport     0
# Diabetes      0
# dtype: int64

# %%
#Clean
dfCSV.dropna(inplace = True)

# %%
#Report missing data
dfCSV.isna().sum()
# Out:
# Timestamp     0
# Medication    0
# Family        0
# Age           0
# Gender        0
# Height        0
# Weight        0
# Status        0
# Income        0
# Location      0
# Education     0
# Active        0
# Exercise      0
# Veges         0
# Water         0
# Sugar         0
# Outside       0
# Meal          0
# Snack         0
# Smoke         0
# Concious      0
# Stress        0
# Sleep         0
# Screen        0
# Transport     0
# Diabetes      0
# dtype: int64

# %%
dfCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518 entries, 0 to 518
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   518 non-null    object
#  1   Medication  518 non-null    object
#  2   Family      518 non-null    object
#  3   Age         518 non-null    int64
#  4   Gender      518 non-null    object
#  5   Height      518 non-null    float64
#  6   Weight      518 non-null    float64
#  7   Status      518 non-null    object
#  8   Income      518 non-null    int64
#  9   Location    518 non-null    object
#  10  Education   518 non-null    object
#  11  Active      518 non-null    object
#  12  Exercise    518 non-null    float64
#  13  Veges       518 non-null    object
#  14  Water       518 non-null    int64
#  15  Sugar       518 non-null    float64
#  16  Outside     518 non-null    int64
#  17  Meal        518 non-null    int64
#  18  Snack       518 non-null    int64
# ...

# %%
dfCSV.head()
# Out:
#             Timestamp Medication Family  Age  Gender  Height  Weight   Status  \
# 0  5/20/2025 17:23:47         No     No   20  Female   151.0    55.0   Single
# 1  5/20/2025 17:28:08         No     No   22  Female   150.0    80.0   Single
# 2  5/20/2025 17:28:55         No    Yes   22  Female   150.0    45.0   Single
# 3  5/20/2025 17:29:48        Yes    Yes   22    Male   167.0    58.0   Single
# 4  5/20/2025 17:41:43         No    Yes   33  Female   159.0    88.0  Married
#
#    Income    Location  ... Outside Meal  Snack Smoke  Concious  \
# 0       0  Semi-urban  ...       7    2      1    No       Yes
# 1       0       Rural  ...       2    2      0    No       Yes
# 2       0  Semi-urban  ...       0    2      1    No       Yes
# 3    1100       Rural  ...       7    2      0    No       Yes
# 4    3000  Semi-urban  ...       4    3      2    No       Yes
#
#                  Stress  Sleep  Screen      Transport Diabetes
# ...

# %%
import pandas as pd

# Define thresholds for each column
thresholds = {
    'Age': 100,
    'Sleep': 24,
    'Screen': 24,
    'Water': 30,
    'Sugar': 30,
    'Outside': 7,
    'Meal': 24,
    'Snack': 24,
    'Exercise': 7,
    'Height': 251,
    'Weight': 635
}

# Loop to fix datatypes, detect & replace outliers
for col, max_val in thresholds.items():
    if col in dfCSV.columns:
        # Convert to numeric (forcefully), ignore errors
        dfCSV[col] = pd.to_numeric(dfCSV[col], errors='coerce')

        # Calculate mask for outliers
        outlier_mask = dfCSV[col] > max_val
        outlier_count = outlier_mask.sum()

        if outlier_count > 0:
            median_val = dfCSV[col].median()
            dfCSV.loc[outlier_mask, col] = median_val
            print(f"Replaced {outlier_count} outliers in '{col}' (> {max_val}) with median: {median_val}")
        else:
            print(f"No outliers found in '{col}' (> {max_val})")
    else:
        print(f"Column '{col}' not found in DataFrame")
# Out:
# Replaced 1 outliers in 'Age' (> 100) with median: 48.0
# Replaced 5 outliers in 'Sleep' (> 24) with median: 6.0
# No outliers found in 'Screen' (> 24)
# Replaced 1 outliers in 'Water' (> 30) with median: 6.0
# Replaced 2 outliers in 'Sugar' (> 30) with median: 2.0
# Replaced 7 outliers in 'Outside' (> 7) with median: 3.0
# Replaced 5 outliers in 'Meal' (> 24) with median: 3.0
# No outliers found in 'Snack' (> 24)
# Replaced 1 outliers in 'Exercise' (> 7) with median: 1.0
# No outliers found in 'Height' (> 251)
# No outliers found in 'Weight' (> 635)

# %%
#Data transformation
from sklearn.preprocessing import LabelEncoder
var_mod = ['Medication', 'Family', 'Gender', 'Status', 'Location', 'Education', 'Active', 'Veges', 'Smoke', 'Concious', 'Stress', 'Transport', 'Diabetes']
le = LabelEncoder()
for i in var_mod:
    dfCSV[i] = le.fit_transform(dfCSV[i])

# %%
#Drop except features and label
dfCSV = dfCSV.drop(['Timestamp'], axis = 1)

# %%
dfCSV.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       0   20       0   151.0    55.0       1       0         1
# 1           0       0   22       0   150.0    80.0       1       0         0
# 2           0       1   22       0   150.0    45.0       1       0         1
# 3           1       1   22       1   167.0    58.0       1    1100         0
# 4           0       1   33       0   159.0    88.0       0    3000         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          0  ...        7     2      1      0         1       3      6
# 1          0  ...        2     2      0      0         1       1      4
# 2          1  ...        0     2      1      0         1       3      6
# 3          0  ...        7     2      0      0         1       0      5
# 4          1  ...        4     3      2      0         1       3      6
#
#    Screen  Transport  Diabetes
# 0       6          2         0
# ...

# %%
#Create a dataset file (after: drop missing data, transformation, drop columns )
dfCSV.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT.csv', index = None, header=True)

# %%
# Read data from external file
import pandas as pd
df = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Medication  518 non-null    int64
#  1   Family      518 non-null    int64
#  2   Age         518 non-null    int64
#  3   Gender      518 non-null    int64
#  4   Height      518 non-null    float64
#  5   Weight      518 non-null    float64
#  6   Status      518 non-null    int64
#  7   Income      518 non-null    int64
#  8   Location    518 non-null    int64
#  9   Education   518 non-null    int64
#  10  Active      518 non-null    int64
#  11  Exercise    518 non-null    float64
#  12  Veges       518 non-null    int64
#  13  Water       518 non-null    int64
#  14  Sugar       518 non-null    float64
#  15  Outside     518 non-null    int64
#  16  Meal        518 non-null    int64
#  17  Snack       518 non-null    int64
#  18  Smoke       518 non-null    int64
# ...

# %%
df.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       0   20       0   151.0    55.0       1       0         1
# 1           0       0   22       0   150.0    80.0       1       0         0
# 2           0       1   22       0   150.0    45.0       1       0         1
# 3           1       1   22       1   167.0    58.0       1    1100         0
# 4           0       1   33       0   159.0    88.0       0    3000         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          0  ...        7     2      1      0         1       3      6
# 1          0  ...        2     2      0      0         1       1      4
# 2          1  ...        0     2      1      0         1       3      6
# 3          0  ...        7     2      0      0         1       0      5
# 4          1  ...        4     3      2      0         1       3      6
#
#    Screen  Transport  Diabetes
# 0       6          2         0
# ...

# %%
#To slice dataset for features and label
x = df.iloc[:, 0:24] #features
y = df.iloc[:, 24:25] #label

# %%
x.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       0   20       0   151.0    55.0       1       0         1
# 1           0       0   22       0   150.0    80.0       1       0         0
# 2           0       1   22       0   150.0    45.0       1       0         1
# 3           1       1   22       1   167.0    58.0       1    1100         0
# 4           0       1   33       0   159.0    88.0       0    3000         1
#
#    Education  ...  Sugar  Outside  Meal  Snack  Smoke  Concious  Stress  \
# 0          0  ...    2.0        7     2      1      0         1       3
# 1          0  ...    0.0        2     2      0      0         1       1
# 2          1  ...    1.0        0     2      1      0         1       3
# 3          0  ...    1.0        7     2      0      0         1       0
# 4          1  ...    3.0        4     3      2      0         1       3
#
#    Sleep  Screen  Transport
# 0      6       6          2
# ...

# %%
y.head()
# Out:
#    Diabetes
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# To split dataset 90-10, 80-20, 70-30, 60-40
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0, shuffle=True) 

# To combine features and its label 
train = pd.concat([x_train, y_train], axis=1, sort=False)
test = pd.concat([x_test, y_test], axis=1, sort=False)

# Exporting the New Dataset
train.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train.csv', index = None, header=True)
test.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test.csv', index = None, header=True)

# %%
# To create a model/app
# Read data from external file 
import pandas as pd 
d1 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train.csv")

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Medication  414 non-null    int64
#  1   Family      414 non-null    int64
#  2   Age         414 non-null    int64
#  3   Gender      414 non-null    int64
#  4   Height      414 non-null    float64
#  5   Weight      414 non-null    float64
#  6   Status      414 non-null    int64
#  7   Income      414 non-null    int64
#  8   Location    414 non-null    int64
#  9   Education   414 non-null    int64
#  10  Active      414 non-null    int64
#  11  Exercise    414 non-null    float64
#  12  Veges       414 non-null    int64
#  13  Water       414 non-null    int64
#  14  Sugar       414 non-null    float64
#  15  Outside     414 non-null    int64
#  16  Meal        414 non-null    int64
#  17  Snack       414 non-null    int64
#  18  Smoke       414 non-null    int64
# ...

# %%
d1.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       1   63       1   174.0    98.0       0    4500         1
# 1           1       1   56       1   172.0    77.0       0    9000         2
# 2           1       1   59       0   165.0    70.0       0   10000         2
# 3           1       1   43       1   168.0    68.0       0    3400         0
# 4           0       1   41       0   154.0    55.0       0    7500         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          1  ...        3     3      3      1         1       1      5
# 1          0  ...        2     3      1      1         1       1      6
# 2          0  ...        1     2      2      0         1       1      6
# 3          1  ...        2     2      3      1         1       1      5
# 4          0  ...        0     2      1      0         0       2      5
#
#    Screen  Transport  Diabetes
# 0       6          0         1
# ...

# %%
#To slice dataset for features and label
x1 = d1.iloc[:, 0:24] #features
y1 = d1.iloc[:, 24:25] #label

# %%
x1.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       1   63       1   174.0    98.0       0    4500         1
# 1           1       1   56       1   172.0    77.0       0    9000         2
# 2           1       1   59       0   165.0    70.0       0   10000         2
# 3           1       1   43       1   168.0    68.0       0    3400         0
# 4           0       1   41       0   154.0    55.0       0    7500         1
#
#    Education  ...  Sugar  Outside  Meal  Snack  Smoke  Concious  Stress  \
# 0          1  ...    3.0        3     3      3      1         1       1
# 1          0  ...    1.0        2     3      1      1         1       1
# 2          0  ...    1.0        1     2      2      0         1       1
# 3          1  ...    1.0        2     2      3      1         1       1
# 4          0  ...    1.0        0     2      1      0         0       2
#
#    Sleep  Screen  Transport
# 0      5       6          0
# ...

# %%
y1.head()
# Out:
#    Diabetes
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0

# %%
# Convert dataframe to array 
x1 = x1.values 
y1 = y1.values 
y1 = y1.ravel() 
 
# K-Nearest Neighbor
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
from sklearn.neighbors import KNeighborsClassifier 
ModelAKU = KNeighborsClassifier(n_neighbors = 8, metric='hamming', weights='distance', algorithm='ball_tree', leaf_size=20) 

# Above ( ModelAKU = KNeighborsClassifier() ) same as below 
#ModelAKU = KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None) 

ModelAKU.fit(x1, y1) 
yPred1 = ModelAKU.predict(x1) 

# Testing & performance analysis -Training data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y1, yPred1), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Training: Accuracy Score: {0}'.format(skm.accuracy_score(y1, yPred1)) 
plt.title(all_sample_title, size = 15);

# %%
# Read data from external file 
import pandas as pd 
d2 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test.csv")

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Medication  104 non-null    int64
#  1   Family      104 non-null    int64
#  2   Age         104 non-null    int64
#  3   Gender      104 non-null    int64
#  4   Height      104 non-null    float64
#  5   Weight      104 non-null    float64
#  6   Status      104 non-null    int64
#  7   Income      104 non-null    int64
#  8   Location    104 non-null    int64
#  9   Education   104 non-null    int64
#  10  Active      104 non-null    int64
#  11  Exercise    104 non-null    float64
#  12  Veges       104 non-null    int64
#  13  Water       104 non-null    int64
#  14  Sugar       104 non-null    float64
#  15  Outside     104 non-null    int64
#  16  Meal        104 non-null    int64
#  17  Snack       104 non-null    int64
#  18  Smoke       104 non-null    int64
# ...

# %%
d2.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           1       1   46       1   163.0    65.0       0       1         2
# 1           1       0   52       1   174.0    88.0       0    6000         2
# 2           0       0   27       0   167.0    80.0       1    4500         2
# 3           1       0   46       1   166.0    66.0       0    2900         1
# 4           1       0   44       1   180.0   117.0       0    4450         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          0  ...        7     3      2      1         1       3      6
# 1          2  ...        3     2      2      0         1       1      6
# 2          0  ...        7     3      2      0         1       2      8
# 3          1  ...        5     3      1      1         0       2      7
# 4          0  ...        2     2      2      1         1       1      5
#
#    Screen  Transport  Diabetes
# 0      10          0         0
# ...

# %%
#Data slicing 
x2 = d2.iloc[:, 0:24] #features
y2 = d2.iloc[:, 24:25] #label

# %%
x2.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           1       1   46       1   163.0    65.0       0       1         2
# 1           1       0   52       1   174.0    88.0       0    6000         2
# 2           0       0   27       0   167.0    80.0       1    4500         2
# 3           1       0   46       1   166.0    66.0       0    2900         1
# 4           1       0   44       1   180.0   117.0       0    4450         1
#
#    Education  ...  Sugar  Outside  Meal  Snack  Smoke  Concious  Stress  \
# 0          0  ...    1.0        7     3      2      1         1       3
# 1          2  ...    1.0        3     2      2      0         1       1
# 2          0  ...    0.0        7     3      2      0         1       2
# 3          1  ...    2.0        5     3      1      1         0       2
# 4          0  ...    1.0        2     2      2      1         1       1
#
#    Sleep  Screen  Transport
# 0      6      10          0
# ...

# %%
y2.head()
# Out:
#    Diabetes
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
# Convert dataframe to array 
x2 = x2.values 
y2 = y2.values 
y2 = y2.ravel() 

yPred2 = ModelAKU.predict(x2) 
 
# Testing & performance analysis -Testing data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y2, yPred2), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Testing: Accuracy Score: {0}'.format(skm.accuracy_score(y2, yPred2)) 
plt.title(all_sample_title, size = 15);

# %%
# Data Preprocessing
# Read data from external file
import pandas as pd
sample = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/data_input.csv")

# %%
sample.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       1   35       1     175      90       1    4000         2
# 1           1       0   60       0     160      70       3    1500         1
# 2           0       1   28       0     162      59       1    3500         2
# 3           0       0   45       1     170      85       1    6000         0
# 4           1       1   52       0     155      78       1    2000         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          3  ...        5     3      1      0         1       4      5
# 1          2  ...        1     3      2      1         0       0      4
# 2          0  ...        6     2      0      0         1       3      7
# 3          1  ...        1     3      1      1         0       1      6
# 4          2  ...        2     3      1      1         1       4      4
#
#    Screen  Transport  Diabetes
# 0       7          1         1
# ...

# %%
#Data transformation
from sklearn.preprocessing import LabelEncoder
var_mod = ['Medication', 'Family', 'Gender', 'Status', 'Location', 'Education', 'Active', 'Veges', 'Smoke', 'Concious', 'Stress', 'Transport', 'Diabetes']
le = LabelEncoder()
for i in var_mod:
    sample[i] = le.fit_transform(dfCSV[i])

# %%
#Create a dataset file (after: drop missing data, transformation, drop columns )
sample.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/data_sample.csv', index = None, header=True)

# %%
# Data Preprocessing
# Read data from external file
import pandas as pd
Sample = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/data_sample.csv")

# %%
Sample.head()
# Out:
#    Medication  Family  Age  Gender  Height  Weight  Status  Income  Location  \
# 0           0       1   35       1     175      90       1    4000         2
# 1           1       0   60       0     160      70       3    1500         1
# 2           0       1   28       0     162      59       1    3500         2
# 3           0       0   45       1     170      85       1    6000         0
# 4           1       1   52       0     155      78       1    2000         1
#
#    Education  ...  Outside  Meal  Snack  Smoke  Concious  Stress  Sleep  \
# 0          3  ...        5     3      1      0         1       4      5
# 1          2  ...        1     3      2      1         0       0      4
# 2          0  ...        6     2      0      0         1       3      7
# 3          1  ...        1     3      1      1         0       1      6
# 4          2  ...        2     3      1      1         1       4      4
#
#    Screen  Transport  Diabetes
# 0       7          1         1
# ...

# %%
#Predict

newData = [[0, 1, 35, 1, 175, 90, 1, 4000, 2, 3, 1, 4, 3, 6, 3, 5, 3, 1, 0, 1, 4, 5, 7, 1, 1]]

predictionResult = ModelAKU.predict(newData)

if(predictionResult == 0):
    print("Prediction result = Approved = 0")
else:
    print("Prediction result = Rejected = 1 ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[756], line 5
#       1 #Predict
#       3 newData = [[1,1.0,1,0]]
# ----> 5 predictionResult = ModelAKU.predict(newData)
#       7 if(predictionResult == 0):
#       8     print("Prediction result = Approved = 0")
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:274, in KNeighborsClassifier.predict(self, X)
#     272     neigh_dist = None
#     273 else:
# --> 274     neigh_dist, neigh_ind = self.kneighbors(X)
#     276 classes_ = self.classes_
#     277 _y = self._y
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:825, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     823         X = _check_precomputed(X)
#     824     else:
# --> 825         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
# ...
