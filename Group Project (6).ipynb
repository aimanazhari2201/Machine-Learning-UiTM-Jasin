# %%
# Read data from external file 
import pandas as pd 
train1 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train_fold_1.csv")
train2 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train_fold_2.csv")
train3 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train_fold_3.csv")
train4 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Train_fold_4.csv")
test1 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test_fold_1.csv")
test2 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test_fold_2.csv")
test3 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test_fold_3.csv")
test4 = pd.read_csv("C:/Users/User/OneDrive/Documents/Group Project/group_project_dataIT-Test_fold_4.csv")

# %%
# Data slicing 
xtrain1 = train1.iloc[:, 0:24] #features
ytrain1 = train1.iloc[:, 24:25] #label
xtrain2 = train2.iloc[:, 0:24] #features
ytrain2 = train2.iloc[:, 24:25] #label
xtrain3 = train3.iloc[:, 0:24] #features
ytrain3 = train3.iloc[:, 24:25] #label
xtrain4 = train4.iloc[:, 0:24] #features
ytrain4 = train4.iloc[:, 24:25] #label
xtest1 = test1.iloc[:, 0:24] #features
ytest1 = test1.iloc[:, 24:25] #label
xtest2 = test2.iloc[:, 0:24] #features
ytest2 = test2.iloc[:, 24:25] #label
xtest3 = test3.iloc[:, 0:24] #features
ytest3 = test3.iloc[:, 24:25] #label
xtest4 = test4.iloc[:, 0:24] #features
ytest4 = test4.iloc[:, 24:25] #label

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain1 = xtrain1.values
ytrain1 = ytrain1.values.ravel()
xtest1 = xtest1.values
ytest1 = ytest1.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 310
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='brute',
        leaf_size=10,
        metric='hamming'
    )
    model.fit(xtrain1, ytrain1)
    y_pred1 = model.predict(xtest1)
    acc = accuracy_score(ytest1, y_pred1)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/knn_hamming_brute_10_accuracy_results_1.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Hamming)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 310
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='hamming'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/knn_hamming_auto_50_accuracy_results_2.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Hamming)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain3 = xtrain3.values
ytrain3 = ytrain3.values.ravel()
xtest3 = xtest3.values
ytest3 = ytest3.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 311
for k in range(1, 312):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='hamming'
    )
    model.fit(xtrain3, ytrain3)
    y_pred3 = model.predict(xtest3)
    acc = accuracy_score(ytest3, y_pred3)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/knn_hamming_auto_50_accuracy_results_3.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Hamming)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain4 = xtrain4.values
ytrain4 = ytrain4.values.ravel()
xtest4 = xtest4.values
ytest4 = ytest4.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 311
for k in range(1, 312):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='hamming'
    )
    model.fit(xtrain4, ytrain4)
    y_pred4 = model.predict(xtest4)
    acc = accuracy_score(ytest4, y_pred4)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/knn_hamming_auto_50_accuracy_results_4.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Hamming)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
import pandas as pd
df = pd.read_csv('C:/Users/User/OneDrive/Documents/Group Project/knn_hamming_brute_40_accuracy_results_4.csv')
max_accuracy = df['test_accuracy'].max()
best_rows = df[df['test_accuracy'] == max_accuracy]
best_rows
# Out:
#     n_neighbors  test_accuracy
# 98           99        0.92233

# %%
#highlight_hamming
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='hamming'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_hamming.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Hamming)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_minkowski(p=1)
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        p=1,
        metric='minkowski'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_minkowski(p=1).csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Minkowski(p=1))', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_minkowski(p=2)
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        p=2,
        metric='minkowski'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_minkowski(p=2).csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Minkowski (p=2))', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_euclidean
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='euclidean'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_euclidean.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Euclidean)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_manhattan
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='manhattan'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_manhattan.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Manhattan)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_chebyshev
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='chebyshev'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_chebyshev.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Chebyshev)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_cosine
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='cosine'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_cosine.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Cosine)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_canberra
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='canberra'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_canberra.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Metric = Canberra)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_uniform
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='uniform',
        algorithm='auto',
        leaf_size=50,
        metric='manhattan'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_uniform.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Weights = Uniform)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv

# %%
#highlight_distance
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Make sure your test and train data are numpy arrays
xtrain2 = xtrain2.values
ytrain2 = ytrain2.values.ravel()
xtest2 = xtest2.values
ytest2 = ytest2.values.ravel()

# List to store results
results = []

# Loop from n_neighbors = 1 to 350
for k in range(1, 311):
    model = KNeighborsClassifier(
        n_neighbors=k,
        weights='distance',
        algorithm='auto',
        leaf_size=50,
        metric='manhattan'
    )
    model.fit(xtrain2, ytrain2)
    y_pred2 = model.predict(xtest2)
    acc = accuracy_score(ytest2, y_pred2)
    results.append({'n_neighbors': k, 'test_accuracy': acc})

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV
df_results.to_csv(r'C:/Users/User/OneDrive/Documents/Group Project/highlight_distance.csv', index = None, header=True)
print("Saved to knn_hamming_accuracy_results.csv")

# Plot accuracy vs k
plt.figure(figsize=(12, 6))
plt.plot(df_results['n_neighbors'], df_results['test_accuracy'], marker='o', color='blue')
plt.title('Test Accuracy vs n_neighbors (Weights = Distance)', fontsize=14)
plt.xlabel('n_neighbors (k)')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved to knn_hamming_accuracy_results.csv
